# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
df = pd.read_csv('product_analytics.csv')
df
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 2      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 3      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 4      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# ...             ...           ...          ...                      ...
# 99995  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99996  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99997  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99998  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99999  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2017-10-22 19:14:13       2017-10-26 22:19:52
# 2      2017-10-22 19:14:13       2017-10-26 22:19:52
# 3      2017-10-22 19:14:13       2017-10-26 22:19:52
# 4      2017-10-22 19:14:13       2017-10-26 22:19:52
# ...                    ...                       ...
# 99995  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99996  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99997  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99998  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99999  2017-09-23 18:44:28       2017-09-28 18:48:56
#
#       order_estimated_delivery_date    product_id     seller_id   price  \
# 0                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 1                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 2                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 3                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 4                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# ...                             ...           ...           ...     ...
# 99995                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99996                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99997                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99998                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99999                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
#
#        shipping_charges product_category_name  product_weight_g  \
# 0                 84.65                  toys             491.0
# 1                 84.65                  toys             491.0
# 2                 84.65                  toys             491.0
# 3                 84.65                  toys             491.0
# 4                 84.65                  toys             491.0
# ...                 ...                   ...               ...
# 99995             59.62                  toys            1383.0
# 99996             59.62                  toys            1383.0
# 99997             59.62                  toys            1383.0
# 99998             59.62                  toys            1383.0
# 99999             59.62                  toys            1383.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 0                   19.0               12.0              16.0
# 1                   19.0               12.0              16.0
# 2                   19.0               12.0              16.0
# 3                   19.0               12.0              16.0
# 4                   19.0               12.0              16.0
# ...                  ...                ...               ...
# 99995               50.0               10.0              40.0
# 99996               50.0               10.0              40.0
# 99997               50.0               10.0              40.0
# 99998               50.0               10.0              40.0
# 99999               50.0               10.0              40.0
#
#        payment_sequential payment_type  payment_installments  payment_value  \
# 0                       1  credit_card                     1         259.14
# 1                       1  credit_card                     1         259.14
# 2                       1  credit_card                     1         259.14
# 3                       1  credit_card                     1         259.14
# 4                       1  credit_card                     1         259.14
# ...                   ...          ...                   ...            ...
# 99995                   1  credit_card                     2        2759.95
# 99996                   1  credit_card                     2        2759.95
# 99997                   1  credit_card                     2        2759.95
# 99998                   1  credit_card                     2        2759.95
# 99999                   1  credit_card                     2        2759.95
#
#        customer_zip_code_prefix    customer_city customer_state
# 0                         58125  varzea paulista             SP
# 1                         58125  varzea paulista             SP
# 2                         58125  varzea paulista             SP
# 3                         58125  varzea paulista             SP
# 4                         58125  varzea paulista             SP
# ...                         ...              ...            ...
# 99995                     56327        guarulhos             SP
# 99996                     56327        guarulhos             SP
# 99997                     56327        guarulhos             SP
# 99998                     56327        guarulhos             SP
# 99999                     56327        guarulhos             SP
#
# [100000 rows x 23 columns]

# %%
# Data dictionary: variable descriptions

data_dict = {
    "Nama Variabel": [
        "order_id", "customer_id", "order_status",
        "order_purchase_timestamp", "order_approved_at",
        "order_delivered_timestamp", "order_estimated_delivery_date",
        "product_id", "seller_id", "price", "shipping_charges",
        "product_category_name", "product_weight_g",
        "product_length_cm", "product_height_cm", "product_width_cm",
        "payment_sequential", "payment_type",
        "payment_installments", "payment_value",
        "customer_zip_code_prefix", "customer_city", "customer_state"
    ],
    "Deskripsi": [
        "ID unik setiap order",
        "ID unik setiap customer",
        "Status pesanan",
        "Waktu pembelian dilakukan",
        "Waktu order disetujui",
        "Waktu order diterima customer",
        "Estimasi tanggal pengiriman",
        "ID unik produk",
        "ID unik seller",
        "Harga produk",
        "Biaya pengiriman",
        "Kategori produk",
        "Berat produk (gram)",
        "Panjang produk (cm)",
        "Tinggi produk (cm)",
        "Lebar produk (cm)",
        "Urutan pembayaran jika lebih dari satu",
        "Jenis metode pembayaran",
        "Jumlah cicilan pembayaran",
        "Total nilai pembayaran",
        "Kode pos customer",
        "Kota customer",
        "State/provinsi customer"
    ]
}

df_dictionary = pd.DataFrame(data_dict)

df_dictionary
# Out:
#                     Nama Variabel                               Deskripsi
# 0                        order_id                    ID unik setiap order
# 1                     customer_id                 ID unik setiap customer
# 2                    order_status                          Status pesanan
# 3        order_purchase_timestamp               Waktu pembelian dilakukan
# 4               order_approved_at                   Waktu order disetujui
# 5       order_delivered_timestamp           Waktu order diterima customer
# 6   order_estimated_delivery_date             Estimasi tanggal pengiriman
# 7                      product_id                          ID unik produk
# 8                       seller_id                          ID unik seller
# 9                           price                            Harga produk
# 10               shipping_charges                        Biaya pengiriman
# 11          product_category_name                         Kategori produk
# 12               product_weight_g                     Berat produk (gram)
# 13              product_length_cm                     Panjang produk (cm)
# 14              product_height_cm                      Tinggi produk (cm)
# 15               product_width_cm                       Lebar produk (cm)
# 16             payment_sequential  Urutan pembayaran jika lebih dari satu
# 17                   payment_type                 Jenis metode pembayaran
# 18           payment_installments               Jumlah cicilan pembayaran
# 19                  payment_value                  Total nilai pembayaran
# 20       customer_zip_code_prefix                       Kode pos customer
# 21                  customer_city                           Kota customer
# 22                 customer_state                 State/provinsi customer

# %% [markdown]
# # Summary Information

# %%
# identify summary dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       100000 non-null  object
#  1   customer_id                    100000 non-null  object
#  2   order_status                   100000 non-null  object
#  3   order_purchase_timestamp       100000 non-null  object
#  4   order_approved_at              100000 non-null  object
#  5   order_delivered_timestamp      98464 non-null   object
#  6   order_estimated_delivery_date  100000 non-null  object
#  7   product_id                     100000 non-null  object
#  8   seller_id                      100000 non-null  object
#  9   price                          100000 non-null  float64
#  10  shipping_charges               100000 non-null  float64
#  11  product_category_name          99981 non-null   object
#  12  product_weight_g               99986 non-null   float64
#  13  product_length_cm              99986 non-null   float64
#  14  product_height_cm              99986 non-null   float64
#  15  product_width_cm               99986 non-null   float64
#  16  payment_sequential             100000 non-null  int64
#  17  payment_type                   100000 non-null  object
#  18  payment_installments           100000 non-null  int64
#  19  payment_value                  100000 non-null  float64
#  20  customer_zip_code_prefix       100000 non-null  int64
#  21  customer_city                  100000 non-null  object
#  22  customer_state                 100000 non-null  object
# dtypes: float64(7), int64(3), object(13)
# memory usage: 17.5+ MB

# %%
# identify missing value

df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_timestamp        1536
# order_estimated_delivery_date       0
# product_id                          0
# seller_id                           0
# price                               0
# shipping_charges                    0
# product_category_name              19
# product_weight_g                   14
# product_length_cm                  14
# product_height_cm                  14
# product_width_cm                   14
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# dtype: int64

# %%
# identify duplicate

df.duplicated().sum()
# Out:
# np.int64(96360)

# %%
# identify percentage of missing value
missing_percentage = df.isnull().sum() * 100 / len(df)
missing_percentage

# ringkasan keputusan untuk missing value
def missing_decision(pct):
    if pct < 5:
        return "Safe to Remove"
    elif 5 <= pct < 20:
        return "Consider the Context"
    elif 20 <= pct <= 40:
        return "Better to Impute"
    else:
        return "Consider dropping the column"

missing_summary = pd.DataFrame({'Persentase Missing (%)': missing_percentage})
missing_summary['Keputusan'] = missing_summary['Persentase Missing (%)'].apply(missing_decision)
missing_summary = missing_summary.sort_values(by='Persentase Missing (%)',ascending=False)
missing_summary
# Out:
#                                Persentase Missing (%)       Keputusan
# order_delivered_timestamp                       1.536  Safe to Remove
# product_category_name                           0.019  Safe to Remove
# product_weight_g                                0.014  Safe to Remove
# product_width_cm                                0.014  Safe to Remove
# product_height_cm                               0.014  Safe to Remove
# product_length_cm                               0.014  Safe to Remove
# customer_city                                   0.000  Safe to Remove
# customer_zip_code_prefix                        0.000  Safe to Remove
# payment_value                                   0.000  Safe to Remove
# payment_installments                            0.000  Safe to Remove
# payment_type                                    0.000  Safe to Remove
# payment_sequential                              0.000  Safe to Remove
# order_id                                        0.000  Safe to Remove
# customer_id                                     0.000  Safe to Remove
# shipping_charges                                0.000  Safe to Remove
# price                                           0.000  Safe to Remove
# seller_id                                       0.000  Safe to Remove
# product_id                                      0.000  Safe to Remove
# order_estimated_delivery_date                   0.000  Safe to Remove
# order_approved_at                               0.000  Safe to Remove
# order_purchase_timestamp                        0.000  Safe to Remove
# order_status                                    0.000  Safe to Remove
# customer_state                                  0.000  Safe to Remove

# %%
# identify unique value

unique_summary = pd.DataFrame({
    'n_unique': df.nunique(),
    'unique_values': df.apply(lambda x: x.unique())
})

unique_summary
# Out:
#                                n_unique  \
# order_id                           3640
# customer_id                        3640
# order_status                          5
# order_purchase_timestamp           3581
# order_approved_at                  3564
# order_delivered_timestamp          3499
# order_estimated_delivery_date       397
# product_id                         2854
# seller_id                          1061
# price                              1117
# shipping_charges                   1589
# product_category_name                54
# product_weight_g                    624
# product_length_cm                    82
# product_height_cm                    76
# product_width_cm                     69
# payment_sequential                   14
# payment_type                          4
# payment_installments                 19
# payment_value                      3092
# customer_zip_code_prefix           2774
# customer_city                       910
# customer_state                       25
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            unique_values
# order_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Axfy13Hk4PIk, v6px92oS8cLG, Ulpf9skrhjfm, bwJVWupf2keN, Dd0QnrMk9Cj5, VjTVGzqe8U6R, xNba906m4TM1, VEDSMTavbQwk, DzNM8wrcMGFH, NpJz7zF9U1ae, mHyhzcUeLGj2, StM5K4TLyrt5, Q97dFuo1kaq9, 07j6mlMhSVtx, kxa1InBj9gwP, P5R6jr1qZdh4, HqV5f8K2UYoA, j5rwgECNf14O, 43It0OEHVyJe, ddXx4T93MeaI, NXDsEGbl1pUC, MhDudBaAab78, XupzjrovQeez, YTztQOHlvuBg, xfXLgLbCo5BC, gVMP1bPDg69L, 9G9EHbafs7NW, INolFarYfmEO, LV0vJIDricq1, VtQvdStc00Xd, tOTdnjpI8Udp, ebR5efLCCpiq, YOKYMSjKRCMN, 57XZHymoJ10l, yUz40ih0jYGt, IeZYtitws7WU, ZPkh9QhjG7SK, KJL5uJuZzKxr, SelY2hgVvruM, 0QqNX4x
iba, ribeirao preto, santana do acarau, curitiba, atibaia, recife, florianopolis, rio de janeiro, taubate, santa ines, santos, araras, santa cruz do rio pardo, cubatao, itapolis, porto alegre, timoteo, claudio, bofete, manhuacu, tatui, governador valadares, parnaiba, carapicuiba, bom jesus da penha, itu, nilopolis, sao bernardo do campo, caiua, bom jesus, primavera do leste, itajai, niteroi, araraquara, piracicaba, joinville, ibirite, palhoca, itupeva, monte azul paulista, concordia, osasco, jundiai, januaria, campinas, dom pedrito, passo fundo, dourados, assis, acarau, vera, betim, resende, maua, telemaco borba, peruibe, monte carmelo, buenopolis, paranaita, caxias do sul, teresina, cascavel, salvador, lagoa d'anta, paranagua, matupa, sao jose dos campos, lencois paulista, campo mourao, ...]
# customer_state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [SP, RJ, MG, SC, ES, RN, BA, DF, RS, PE, GO, CE, PR, MA, PI, MT, MS, SE, RO, TO, AM, AP, PB, PA, AL]

# %%
# identiy abbreviation of customer_state

state_mapping = {
    "SP": "São Paulo",
    "RJ": "Rio de Janeiro",
    "MG": "Minas Gerais",
    "SC": "Santa Catarina",
    "ES": "Espírito Santo",
    "RN": "Rio Grande do Norte",
    "BA": "Bahia",
    "DF": "Distrito Federal",
    "RS": "Rio Grande do Sul",
    "PE": "Pernambuco",
    "GO": "Goiás",
    "CE": "Ceará",
    "PR": "Paraná",
    "MA": "Maranhão",
    "PI": "Piauí",
    "MT": "Mato Grosso",
    "MS": "Mato Grosso do Sul",
    "SE": "Sergipe",
    "RO": "Rondônia",
    "TO": "Tocantins",
    "AM": "Amazonas",
    "AP": "Amapá",
    "PB": "Paraíba",
    "PA": "Pará",
    "AL": "Alagoas"
}

state_df = pd.DataFrame(
    list(state_mapping.items()),
    columns=["State Code", "State Name"]
)

state_df
# Out:
#    State Code           State Name
# 0          SP            São Paulo
# 1          RJ       Rio de Janeiro
# 2          MG         Minas Gerais
# 3          SC       Santa Catarina
# 4          ES       Espírito Santo
# 5          RN  Rio Grande do Norte
# 6          BA                Bahia
# 7          DF     Distrito Federal
# 8          RS    Rio Grande do Sul
# 9          PE           Pernambuco
# 10         GO                Goiás
# 11         CE                Ceará
# 12         PR               Paraná
# 13         MA             Maranhão
# 14         PI                Piauí
# 15         MT          Mato Grosso
# 16         MS   Mato Grosso do Sul
# 17         SE              Sergipe
# 18         RO             Rondônia
# 19         TO            Tocantins
# 20         AM             Amazonas
# 21         AP                Amapá
# 22         PB              Paraíba
# 23         PA                 Pará
# 24         AL              Alagoas

# %%
# identify outliers

def detect_outliers_iqr(df):
    outlier_summary = {}
    total_rows = df.shape[0]
    
    numeric_cols = df.select_dtypes(include='number').columns
    
    for col in numeric_cols:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1

        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr

        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_count = outliers.shape[0]
        outlier_percentage = (outlier_count / total_rows) * 100

        outlier_summary[col] = {
            'lower_bound': lower_bound,
            'upper_bound': upper_bound,
            'outlier_count': outlier_count,
            'outlier_percentage (%)': round(outlier_percentage, 2)
        }

    return pd.DataFrame(outlier_summary).T


outlier_summary = detect_outliers_iqr(df)
outlier_summary
# Out:
#                           lower_bound  upper_bound  outlier_count  \
# price                        -624.735     1278.825         9196.0
# shipping_charges              -32.555      106.605         6202.0
# product_weight_g            -1635.000     3781.000        12005.0
# product_length_cm             -13.000       75.000          537.0
# product_height_cm              -8.000       40.000         3038.0
# product_width_cm               -7.500       52.500         1215.0
# payment_sequential              1.000        1.000         3772.0
# payment_installments           -2.000        6.000         9246.0
# payment_value                -290.690      712.110         8678.0
# customer_zip_code_prefix   -78549.500   156662.500            0.0
#
#                           outlier_percentage (%)
# price                                       9.20
# shipping_charges                            6.20
# product_weight_g                           12.01
# product_length_cm                           0.54
# product_height_cm                           3.04
# product_width_cm                            1.21
# payment_sequential                          3.77
# payment_installments                        9.25
# payment_value                               8.68
# customer_zip_code_prefix                    0.00

# %% [markdown]
# # Distribution Audit

# %%
# Select continuous numeric variables (float64) for skewness analysis
continuous_cols = df.select_dtypes(include='float64').columns

df[continuous_cols].skew().sort_values(ascending=False)
# Out:
# product_weight_g     3.256821
# payment_value        3.194939
# price                2.929645
# shipping_charges     2.771634
# product_height_cm    2.515345
# product_length_cm    1.042199
# product_width_cm     0.988232
# dtype: float64

# %%
# Histogram for Continuous Variables (float64 only)

import matplotlib.pyplot as plt
import seaborn as sns

float_cols = df.select_dtypes(include='float64').columns

plt.figure(figsize=(18, 10))

for i, col in enumerate(float_cols, 1):
    plt.subplot(4, 3, i)
    sns.histplot(
        df[col],
        kde=True,
        color='teal',
        edgecolor='black',
        alpha=0.7
    )
    plt.title(col, fontsize=11)
    plt.xlabel('')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
# Boxplot for Continuous Variables

plt.figure(figsize=(18, 10))

for i, col in enumerate(float_cols, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(
        x=df[col],
        color='teal',
        flierprops=dict(
        marker='o',
        markerfacecolor='red',
        markersize=5,
        linestyle='none'
    )
    )
    plt.title(col, fontsize=11, fontweight='bold')
    plt.xlabel("")

plt.tight_layout()
plt.show()

# %%
# Countplot for Categorical Integer Variables

int_cols = df.select_dtypes(include='int64').columns

# Filter integer yang kemungkinan kategorikal (unique kecil)
cat_int_cols = [col for col in int_cols if df[col].nunique() < 20]

plt.figure(figsize=(18, 8))

for i, col in enumerate(cat_int_cols, 1):
    plt.subplot(2, 3, i)
    sns.countplot(x=df[col], hue=df[col], palette='viridis', legend=False)
    plt.title(col, fontsize=11)
    plt.xlabel('')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Inisialisasi DataFrame untuk raw data dan proses cleaning

# %%
# raw data

df_raw = df.copy()

# %%
# proses cleaning

df_cleaning = df.copy()

# %% [markdown]
# # Handling Missing Value

# %%
# Handling missing values

# Create state flags
df_cleaning['is_purchased'] = df_cleaning['order_purchase_timestamp'].notna()
df_cleaning['is_approved'] = df_cleaning['order_approved_at'].notna()
df_cleaning['is_delivered'] = df_cleaning['order_delivered_timestamp'].notna()

# Fill missing product category (safe to fill)
df_cleaning['product_category_name'] = df_cleaning['product_category_name'].fillna('Unknown')

# Fill numeric size/weight with median
float_cols = [
    'product_weight_g',
    'product_width_cm',
    'product_height_cm',
    'product_length_cm'
]

for col in float_cols:
    df_cleaning[col] = df_cleaning[col].fillna(df_cleaning[col].median())

# %%
df_cleaning.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_timestamp        1536
# order_estimated_delivery_date       0
# product_id                          0
# seller_id                           0
# price                               0
# shipping_charges                    0
# product_category_name               0
# product_weight_g                    0
# product_length_cm                   0
# product_height_cm                   0
# product_width_cm                    0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# is_purchased                        0
# is_approved                         0
# is_delivered                        0
# dtype: int64

# %%
# handling duplicate

df_cleaning = df_cleaning.drop_duplicates(keep='first')

# %%
df_cleaning.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Standarisasi Tipe Data

# %%
# 1. Define datetime columns
datetime_cols = [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_timestamp',
    'order_estimated_delivery_date'
]

# 2. Convert datetime columns
df_cleaning[datetime_cols] = df_cleaning[datetime_cols].apply(pd.to_datetime)

# 3. Convert remaining object columns to category
object_cols = df_cleaning.select_dtypes(include='object').columns

df_cleaning[object_cols] = df_cleaning[object_cols].astype('category')

# %% [markdown]
# # Load Dataset Before vs After Cleaning

# %%
df_raw
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 2      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 3      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 4      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# ...             ...           ...          ...                      ...
# 99995  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99996  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99997  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99998  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
# 99999  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2017-10-22 19:14:13       2017-10-26 22:19:52
# 2      2017-10-22 19:14:13       2017-10-26 22:19:52
# 3      2017-10-22 19:14:13       2017-10-26 22:19:52
# 4      2017-10-22 19:14:13       2017-10-26 22:19:52
# ...                    ...                       ...
# 99995  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99996  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99997  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99998  2017-09-23 18:44:28       2017-09-28 18:48:56
# 99999  2017-09-23 18:44:28       2017-09-28 18:48:56
#
#       order_estimated_delivery_date    product_id     seller_id   price  \
# 0                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 1                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 2                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 3                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 4                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# ...                             ...           ...           ...     ...
# 99995                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99996                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99997                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99998                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
# 99999                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
#
#        shipping_charges product_category_name  product_weight_g  \
# 0                 84.65                  toys             491.0
# 1                 84.65                  toys             491.0
# 2                 84.65                  toys             491.0
# 3                 84.65                  toys             491.0
# 4                 84.65                  toys             491.0
# ...                 ...                   ...               ...
# 99995             59.62                  toys            1383.0
# 99996             59.62                  toys            1383.0
# 99997             59.62                  toys            1383.0
# 99998             59.62                  toys            1383.0
# 99999             59.62                  toys            1383.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 0                   19.0               12.0              16.0
# 1                   19.0               12.0              16.0
# 2                   19.0               12.0              16.0
# 3                   19.0               12.0              16.0
# 4                   19.0               12.0              16.0
# ...                  ...                ...               ...
# 99995               50.0               10.0              40.0
# 99996               50.0               10.0              40.0
# 99997               50.0               10.0              40.0
# 99998               50.0               10.0              40.0
# 99999               50.0               10.0              40.0
#
#        payment_sequential payment_type  payment_installments  payment_value  \
# 0                       1  credit_card                     1         259.14
# 1                       1  credit_card                     1         259.14
# 2                       1  credit_card                     1         259.14
# 3                       1  credit_card                     1         259.14
# 4                       1  credit_card                     1         259.14
# ...                   ...          ...                   ...            ...
# 99995                   1  credit_card                     2        2759.95
# 99996                   1  credit_card                     2        2759.95
# 99997                   1  credit_card                     2        2759.95
# 99998                   1  credit_card                     2        2759.95
# 99999                   1  credit_card                     2        2759.95
#
#        customer_zip_code_prefix    customer_city customer_state
# 0                         58125  varzea paulista             SP
# 1                         58125  varzea paulista             SP
# 2                         58125  varzea paulista             SP
# 3                         58125  varzea paulista             SP
# 4                         58125  varzea paulista             SP
# ...                         ...              ...            ...
# 99995                     56327        guarulhos             SP
# 99996                     56327        guarulhos             SP
# 99997                     56327        guarulhos             SP
# 99998                     56327        guarulhos             SP
# 99999                     56327        guarulhos             SP
#
# [100000 rows x 23 columns]

# %%
df_cleaning
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 13     v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 16     Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 21     bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 27     Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 99695  cjN5Qz0XrtMP  l6iz9U8zd8qG    delivered      2018-02-27 11:11:22
# 99703  8D2pZAr9VFxc  ge8wKte8vDfD      shipped      2017-07-19 12:44:59
# 99711  aIrTLRPEWsZz  tdBVo6pBogui    delivered      2017-08-23 17:20:02
# 99713  lQa7AIqVpwPZ  35diVOwEjA2F    delivered      2017-11-12 11:11:06
# 99716  GeG4KAwtrR78  uqCUB2mTXtlt    delivered      2017-09-22 15:26:28
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 13    2018-06-20 22:20:20       2018-07-03 22:51:22
# 16    2018-02-17 16:15:35       2018-02-27 01:29:50
# 21    2018-08-18 18:15:16       2018-08-27 20:03:51
# 27    2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 99695 2018-02-27 11:35:40       2018-03-06 18:39:06
# 99703 2017-07-19 12:55:22                       NaT
# 99711 2017-08-23 17:32:46       2017-09-05 21:45:35
# 99713 2017-11-14 04:10:46       2017-11-23 20:09:47
# 99716 2017-09-23 18:44:28       2017-09-28 18:48:56
#
#       order_estimated_delivery_date    product_id     seller_id   price  \
# 0                        2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF  223.51
# 13                       2018-07-24  qejhpMGGVcsl  IjlpYfhUbRQs  170.80
# 16                       2018-03-08  qUS5d2pEAyxJ  77p2EYxcM9MD   64.40
# 21                       2018-09-19  639iGvMyv0De  jWzS0ayv9TGf  264.50
# 27                       2018-01-18  1lycYGcsic2F  l1pYW6GBnPMr  779.90
# ...                             ...           ...           ...     ...
# 99695                    2018-03-28  NmXJXDeHjNcb  lbmduirZT5rh   57.66
# 99703                    2017-08-14  iLnH8fKqZq00  SgeUigb5Vbiv   18.10
# 99711                    2017-09-21  Vluazar8Um8o  LDwBM8FTDl45  206.57
# 99713                    2017-12-05  aUrNFdURGBin  rFT13UJuGo0Q   71.49
# 99716                    2017-10-16  0vbEvli2JYJu  RKad98cTxhSb   95.03
#
#        shipping_charges     product_category_name  product_weight_g  \
# 0                 84.65                      toys             491.0
# 13                23.79             watches_gifts             440.0
# 16                17.38  costruction_tools_garden            2200.0
# 21                30.72                      toys            1450.0
# 27                30.66                      toys             300.0
# ...                 ...                       ...               ...
# 99695            140.52     computers_accessories             220.0
# 99703             20.67                     audio            1075.0
# 99711              1.12              market_place             775.0
# 99713             16.06                      toys             250.0
# 99716             59.62                      toys            1383.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 0                   19.0               12.0              16.0
# 13                  18.0               14.0              17.0
# 16                  16.0               16.0              16.0
# 21                  68.0                3.0              48.0
# 27                  17.0                4.0              12.0
# ...                  ...                ...               ...
# 99695               22.0               13.0              12.0
# 99703               40.0               20.0              30.0
# 99711               35.0                9.0              15.0
# 99713               16.0               16.0              16.0
# 99716               50.0               10.0              40.0
#
#        payment_sequential payment_type  payment_installments  payment_value  \
# 0                       1  credit_card                     1         259.14
# 13                      1  credit_card                     8         382.39
# 16                      1  credit_card                     4         249.25
# 21                      1  credit_card                     2          27.79
# 27                      1  credit_card                     1          76.15
# ...                   ...          ...                   ...            ...
# 99695                   1  credit_card                     1         111.01
# 99703                   1  credit_card                     2         183.12
# 99711                   1  credit_card                     3         494.42
# 99713                   1       wallet                     1         388.51
# 99716                   1  credit_card                     2        2759.95
#
#        customer_zip_code_prefix       customer_city customer_state  \
# 0                         58125     varzea paulista             SP
# 13                         3112  armacao dos buzios             RJ
# 16                         4119             jandira             SP
# 21                        18212          uberlandia             MG
# 27                        88868            ilhabela             SP
# ...                         ...                 ...            ...
# 99695                      6872            valinhos             SP
# 99703                     79134      belo horizonte             MG
# 99711                      8765      belo horizonte             MG
# 99713                      9600            contagem             MG
# 99716                     56327           guarulhos             SP
#
#        is_purchased  is_approved  is_delivered
# 0              True         True          True
# 13             True         True          True
# 16             True         True          True
# 21             True         True          True
# 27             True         True          True
# ...             ...          ...           ...
# 99695          True         True          True
# 99703          True         True         False
# 99711          True         True          True
# 99713          True         True          True
# 99716          True         True          True
#
# [3640 rows x 26 columns]

# %% [markdown]
# # Create a new dataset for visualization stage

# %%
df_cleaning.to_csv('df_cleaning.csv', index = False)

# %%
# validation checking

df_cek = pd.read_csv('df_cleaning.csv')
df_cek.head(10)
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# 5  VjTVGzqe8U6R  UkqnhxmX7YMP    delivered      2017-09-01 14:38:16
# 6  xNba906m4TM1  85jiDiGSfhTu    delivered      2018-04-23 21:03:00
# 7  VEDSMTavbQwk  gDdkaN8b9s1g    delivered      2018-02-23 14:49:39
# 8  DzNM8wrcMGFH  9Csx6oXlpLl1    delivered      2017-11-24 19:12:37
# 9  NpJz7zF9U1ae  gZTPKLPRnreg    delivered      2017-11-30 11:48:21
#
#      order_approved_at order_delivered_timestamp  \
# 0  2017-10-22 19:14:13       2017-10-26 22:19:52
# 1  2018-06-20 22:20:20       2018-07-03 22:51:22
# 2  2018-02-17 16:15:35       2018-02-27 01:29:50
# 3  2018-08-18 18:15:16       2018-08-27 20:03:51
# 4  2017-12-22 17:31:31       2018-01-05 19:22:49
# 5  2017-09-01 14:50:24       2017-09-15 18:57:50
# 6  2018-04-24 18:18:18       2018-04-25 20:14:38
# 7  2018-02-23 15:16:13       2018-04-02 14:12:50
# 8  2017-11-25 04:54:03       2017-12-11 13:09:32
# 9  2017-11-30 13:31:19       2017-12-14 16:38:47
#
#   order_estimated_delivery_date    product_id     seller_id    price  \
# 0                    2017-11-09  90K0C1fIyQUf  ZWM05J9LcBSF   223.51
# 1                    2018-07-24  qejhpMGGVcsl  IjlpYfhUbRQs   170.80
# 2                    2018-03-08  qUS5d2pEAyxJ  77p2EYxcM9MD    64.40
# 3                    2018-09-19  639iGvMyv0De  jWzS0ayv9TGf   264.50
# 4                    2018-01-18  1lycYGcsic2F  l1pYW6GBnPMr   779.90
# 5                    2017-09-26  TpFZIk33uyGn  XePbD5Ocm6Yk   263.90
# 6                    2018-05-04  Y0T4Ca4BXK8U  ftbUjJ6Gsazg   966.90
# 7                    2018-03-15  IUykT5z5LcPW  RKad98cTxhSb  1534.90
# 8                    2017-12-14  0UHKKyYmxWfq  K0qPVGdA91KO   779.00
# 9                    2018-01-03  MJ82dNJNiV7U  2a07LobkzHUx    95.03
#
#    shipping_charges     product_category_name  product_weight_g  \
# 0             84.65                      toys             491.0
# 1             23.79             watches_gifts             440.0
# 2             17.38  costruction_tools_garden            2200.0
# 3             30.72                      toys            1450.0
# 4             30.66                      toys             300.0
# 5             40.26                      toys            2800.0
# 6             98.76            bed_bath_table            3975.0
# 7             66.90                      toys             250.0
# 8             34.86                      toys            1200.0
# 9             60.35                      toys            1500.0
#
#    product_length_cm  product_height_cm  product_width_cm  payment_sequential  \
# 0               19.0               12.0              16.0                   1
# 1               18.0               14.0              17.0                   1
# 2               16.0               16.0              16.0                   1
# 3               68.0                3.0              48.0                   1
# 4               17.0                4.0              12.0                   1
# 5               16.0               31.0              39.0                   1
# 6               46.0               12.0              43.0                   1
# 7               45.0               15.0              35.0                   1
# 8               30.0               23.0              30.0                   1
# 9               30.0                5.0              20.0                   1
#
#   payment_type  payment_installments  payment_value  customer_zip_code_prefix  \
# 0  credit_card                     1         259.14                     58125
# 1  credit_card                     8         382.39                      3112
# 2  credit_card                     4         249.25                      4119
# 3  credit_card                     2          27.79                     18212
# 4  credit_card                     1          76.15                     88868
# 5  credit_card                     4        1014.75                     25902
# 6  credit_card                     1         123.79                      4762
# 7  credit_card                     5         146.51                     75870
# 8       wallet                     1        1521.75                     69068
# 9  credit_card                     6          87.30                     20921
#
#         customer_city customer_state  is_purchased  is_approved  is_delivered
# 0     varzea paulista             SP          True         True          True
# 1  armacao dos buzios             RJ          True         True          True
# 2             jandira             SP          True         True          True
# 3          uberlandia             MG          True         True          True
# 4            ilhabela             SP          True         True          True
# 5         porto uniao             SC          True         True          True
# 6           guarulhos             SP          True         True          True
# 7          mogi-guacu             SP          True         True          True
# 8           bebedouro             SP          True         True          True
# 9           sao paulo             SP          True         True          True

# %%
df_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3640 entries, 0 to 99716
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       3640 non-null   category
#  1   customer_id                    3640 non-null   category
#  2   order_status                   3640 non-null   category
#  3   order_purchase_timestamp       3640 non-null   datetime64[ns]
#  4   order_approved_at              3640 non-null   datetime64[ns]
#  5   order_delivered_timestamp      3559 non-null   datetime64[ns]
#  6   order_estimated_delivery_date  3640 non-null   datetime64[ns]
#  7   product_id                     3640 non-null   category
#  8   seller_id                      3640 non-null   category
#  9   price                          3640 non-null   float64
#  10  shipping_charges               3640 non-null   float64
#  11  product_category_name          3640 non-null   category
#  12  product_weight_g               3640 non-null   float64
#  13  product_length_cm              3640 non-null   float64
#  14  product_height_cm              3640 non-null   float64
#  15  product_width_cm               3640 non-null   float64
#  16  payment_sequential             3640 non-null   int64
#  17  payment_type                   3640 non-null   category
#  18  payment_installments           3640 non-null   int64
#  19  payment_value                  3640 non-null   float64
#  20  customer_zip_code_prefix       3640 non-null   int64
#  21  customer_city                  3640 non-null   category
#  22  customer_state                 3640 non-null   category
#  23  is_purchased                   3640 non-null   bool
#  24  is_approved                    3640 non-null   bool
#  25  is_delivered                   3640 non-null   bool
# dtypes: bool(3), category(9), datetime64[ns](4), float64(7), int64(3)
# memory usage: 972.4 KB
